# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from model_comparer import ModelComparer
import warnings
from matplotlib import pyplot as plt
warnings.filterwarnings('ignore')
from plotting import fig_saver
import gas_phase_data

# %%
import pandas as pd
df = pd.read_csv("md22.csv")

# %%
import sys
sys.path.append("../")
import surp

# %%
mc = ModelComparer(["cristallo11", "c11_cc_fit"])

# %%
plt.rcParams["text.color"] = "black"
plt.rcParams["axes.labelcolor"] = "white"
plt.rcParams["xtick.color"] = "white"
plt.rcParams["ytick.color"] = "white"
plt.rcParams["font.size"] = 20

# %% [markdown]
# # Mean abundance star tracks

# %%
fig, ax = plt.subplots()
ax.set_ylim(-0.5, 0.5)
mc.plot_mean_stars("[o/h]", "[c/o]", xlim=(-0.6, 0.4), ax=ax)

# %%
mc.plot_all_mean_stars()

# %% [markdown]
# # Gas phase tracks

# %%
mc.plot_gas("[o/h]", "[c/o]", filename="analytic_gas")
mc.plot_gas("[o/h]", "[n/o]")
# mc.plot_gas("[fe/h]", "[c/n]")

# %% [markdown]
# # MDFs

# %%
mc.plot_mdf("[o/h]")
mc.plot_mdf("[n/o]")
mc.plot_mdf("[c/n]")
mc.plot_mdf("[c/o]")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-6e6811615a5d> in <module>
#       1 mc.plot_mdf("[o/h]")
#       2 mc.plot_mdf("[n/o]")
# ----> 3 mc.plot_mdf("[c/n]")
#       4 mc.plot_mdf("[c/o]")
#
# ~/surp/model_comparer.py in plot_mdf(self, x, filename)
#     125     def plot_mdf(self, x, filename=None):
#     126         for name, st in self.stars.items():
# --> 127             plt.hist(st[x], 50, histtype="step", label=name, density=True)
#     128
#     129         v21 = aah.vincenzo2021()
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2820         orientation='vertical', rwidth=None, log=False, color=None,
#    2821         label=None, stacked=False, *, data=None, **kwargs):
# -> 2822     return gca().hist(
#    2823         x, bins=bins, range=range, density=density, weights=weights,
#    2824         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6736             # this will automatically overwrite bins,
#    6737             # so that each histogram uses the same bins
# -> 6738             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6739             tops.append(m)
#    6740         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     424             raise ValueError('`bins` must be positive, when an integer')
#     425
# --> 426         first_edge, last_edge = _get_outer_edges(a, range)
#     427
#     428     elif np.ndim(bins) == 1:
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     313                 'max must be larger than min in range parameter.')
#     314         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 315             raise ValueError(
#     316                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#     317     elif a.size == 0:
#
# ValueError: supplied range of [-inf, 0.667051488890593] is not finite

# %% [markdown]
# # Stars

# %%
import numpy as np

# %%
def o_fe_cutoff(fe_h):
    return 0.12 - (fe_h < 0) * 0.13 * fe_h

fe_h = np.linspace(-2, 0.5, 100)
plt.plot(fe_h, o_fe_cutoff(fe_h))
mc.plot_stars("[fe/h]", "[o/fe]", c="high_alpha")

# %%
mc.plot_stars("age", "[c/o]", c="R_origin", xlim=(0, 10))

# %%
mc.plot_stars("[o/h]", "[c/o]", c="R_origin", xlim=(-0.4, 0.4), ylim=(-0.5, 0.2))

# %%
mc.plot_stars("[o/h]", "[c/o]", c="high_alpha", xlim=(-0.4, 0.4), ylim=(-0.2, 0.2), solar_neighborhood=False, filename="cooh_gas_analytic_alpha")

# %%
mc.plot_stars("[o/h]", "[c/n]", c="high_alpha", xlim=(-0.4, 0.4), filename="cnoh_gas_analytic_alpha")

# %%
mc.plot_stars("[o/h]", "[c/o]", c="age", xlim=(-0.4, 0.4), ylim=(-0.5, 0.2))

# %%
mc.plot_stars("[o/h]", "[c/o]", c="R_origin", xlim=(-0.4, 0.4), ylim=(-0.5, 0.2), solar_neighborhood=True)

# %% [markdown]
# # Gas phase tracks

# %%
mc.plot_model_fixed_t(ylim=(-1, 0.2))

# %%
mc.plot_model_fixed_r()
