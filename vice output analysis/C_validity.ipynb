# %% [markdown]
# This notebook is just used to compare models with different simple parameters such as multithreading or resolution and ensure that these do not affect predictions.

# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
from model_comparer import ModelComparer
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/daniel/surp/VICE/vice/__init__.py:141: UserWarning: Using un-released version of VICE
#   warnings.warn("Using un-released version of VICE", UserWarning)

# %%
mc = ModelComparer(["cristallo11_1", "cristallo11_8_stars_1"])

# %%
mc.plot_cooh()

# %%
mc.plot_nooh()

# %%
mc.plot_cnfeh()

# %%
mc.plot_cnooh()

# %%
mc.plot_model_fixed_r()

# %%
mc.plot_gas("[o/h]", "[c/o]")

# %%
mc.plot_stars("age", "[c/o]", c="R_origin")

# %%
mc.plot_stars("[o/h]", "[c/o]", c="R_origin", xlim=(-0.4, 0.4), ylim=(-0.5, 0.2))

# %%
mc.plot_model_fixed_t(ylim=(-1, 0.2))

# %%
mc.plot_mdf("[c/h]")

# %%
mc.plot_mdf("[n/h]")

# %%
mc.plot_mdf("[c/n]")
