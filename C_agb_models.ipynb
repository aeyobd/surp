# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
from model_comparer import ModelComparer
import warnings
warnings.filterwarnings('ignore')
from plotting import fig_saver

# %%
mc = ModelComparer(["cristallo11", "karakas10", "ventura13", "karakas16"])

# %%
sf = fig_saver("figures")

# %%
mc.plot_cooh()
sf("cooh_agb_models")

# %%
mc.plot_nooh()
sf("nooh_agb_models")

# %%
mc.plot_cnfeh()
sf("cnfeh_agb_models")

# %%
mc.plot_cnooh()
sf("cnooh_agb_models")

# %%
mc.plot_model_fixed_r()

# %%
mc.plot_gas("[o/h]", "[c/o]")

# %%
mc.plot_stars("age", "[c/o]", c="R_origin")

# %%
mc.plot_stars("[o/h]", "[c/o]", c="R_origin", xlim=(-0.4, 0.4), ylim=(-0.5, 0.2))

# %%
mc.plot_stars("[o/h]", "[c/n]", c="R_origin")

# %%
mc.plot_stars("[o/h]", "[n/o]", c="R_origin")

# %%
mc.plot_model_fixed_t(ylim=(-1, 0.2))
