# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import apogee_analysis as aah

# %%
v21 = aah.vincenzo2021()
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
v21
# Out:
#        [mg/fe]    [fe/h]    [c/fe]    [n/fe]     [c/h]     [n/h]   age  \
# 0     0.247532 -0.292042  0.158510  0.052401 -0.069385 -0.436210  10.1
# 1     0.042202  0.049127 -0.016018  0.197207  0.113361  0.006940   8.5
# 2     0.290692 -0.351292  0.153900  0.091762 -0.122959 -0.484260   8.8
# 3     0.027853 -0.178222 -0.012749  0.202450 -0.069914 -0.290230   3.6
# 4     0.257632 -0.211932  0.168140  0.196530  0.010191 -0.179516  13.7
# ...        ...       ...       ...       ...       ...       ...   ...
# 5071  0.054724 -0.221732 -0.112970  0.360880 -0.153254 -0.250104   1.6
# 5072  0.063233  0.008628 -0.007638  0.167090  0.081244 -0.063674   9.1
# 5073  0.109576  0.281778  0.107047  0.196150  0.447155  0.301935  11.1
# 5074 -0.041400  0.154678 -0.060001  0.448730  0.266917  0.225569   1.0
# 5075  0.069604 -0.034680 -0.007604  0.140335  0.069894 -0.194662   4.1
#
#          [c/n]     [o/h]     [n/o]     [c/o]   [c+n/h]   [c+n/o]  high_alpha
# 0     0.376624 -0.079585 -0.356624  0.010201 -0.129447 -0.049862        True
# 1     0.116219  0.073644 -0.066703  0.039717  0.091440  0.017796       False
# 2     0.371100 -0.169290 -0.314970  0.046331 -0.182400 -0.013110        True
# 3     0.230115 -0.128322 -0.161908  0.058408 -0.110926  0.017395       False
# 4     0.199505  0.014441 -0.193956 -0.004250 -0.026094 -0.040535        True
# ...        ...       ...       ...       ...       ...       ...         ...
# 5071  0.106649 -0.229760 -0.020344  0.076506 -0.173374  0.056385       False
# 5072  0.154717  0.041089 -0.104763  0.040155  0.052400  0.011311       False
# 5073  0.155018  0.364991 -0.063056  0.082164  0.418258  0.053267       False
# 5074  0.051146  0.167322  0.058247  0.099595  0.257891  0.090569       False
# 5075  0.274354  0.026158 -0.220820  0.043736  0.022531 -0.003627       False
#
# [4875 rows x 14 columns]

# %%
aah.plot_v21("[o/h]", "[c/o]")
aah.plot_mean_v21("[o/h]", "[c/o]")
plt.xlim(-0.8)
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (-0.8, 0.5657935378599313)

# %%
aah.plot_v21("[o/h]", "[c/o]", exclude_high_alpha=False)
aah.plot_mean_v21("[o/h]", "[c/o]", exclude_high_alpha=False)
plt.xlim(-0.8)
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (-0.8, 0.6024140318872695)

# %%
aah.calc_mean_v21("[o/h]", "[c/o]")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-5b50e2fb0d3a> in <module>
# ----> 1 aah.calc_mean_v21("[o/h]", "[c/o]")
#
# AttributeError: module 'apogee_analysis' has no attribute 'calc_mean_v21'

# %%
aah.plot_mean_v21("[o/h]", "[c/o]")
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
aah.plot_mean_v21("[o/h]", "[c/o]");
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import numpy as np

# %%
df = v21[v21["high_alpha"]]
bins, means_low_a, sds, counts = aah.calc_mean(df["[o/h]"], df["[c/o]"])
plt.scatter(df["[o/h]"], df["[c/o]"], s=0.1, label="high a")

o_h = bins[:-1]

plt.errorbar(bins[:-1], means_low_a, color="purple", zorder=1, yerr=sds, fmt="o")


df = v21[~v21["high_alpha"]]
bins, means_high_a, sds, counts = aah.calc_mean(df["[o/h]"], df["[c/o]"])


plt.scatter(df["[o/h]"], df["[c/o]"], s=0.1, label="low a")
plt.errorbar(bins[:-1], means_high_a, color="k", zorder=1, yerr=sds, fmt="o")

plt.legend()
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
plt.xlim(-0.5)
# Out:
# (-0.5, 0.6024140318872695)

# %%
aah.plot_v21("[o/h]", "[c/o]", exclude_high_alpha=False)
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(v21["[fe/h]"], v21["[o/fe]"], c=v21["high_alpha"], s=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bfb02d2b6f04> in <module>
# ----> 1 plt.scatter(v21["[fe/h]"], v21["[o/fe]"], c=v21["high_alpha"], s=1)
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(v21["[o/h]"] - v21["[fe/h]"], v21["[c/o]"], c=v21["[c/h]"], s=1)
plt.colorbar(label="[O/H]")
plt.xlabel("alpha/fe")
plt.ylabel("[c/o]")
# Out:
# Text(0, 0.5, '[c/o]')

# %%
plt.scatter(v21["[o/h]"] - v21["[fe/h]"], v21["[mg/fe]"] + v21["[fe/h]"] - v21["[o/h]"], c=v21["[c/h]"], s=1)
plt.colorbar(label="[O/H]")
plt.xlabel("alpha/fe")
plt.ylabel("[c/o]")
# Out:
# Text(0, 0.5, '[c/o]')
