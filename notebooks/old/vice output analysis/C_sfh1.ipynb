# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
from model_comparer import ModelComparer
import warnings
from matplotlib import pyplot as plt
warnings.filterwarnings('ignore')
from plotting_utils import fig_saver
import gas_phase_data

# %%
import sys
sys.path.append("../")
import surp
import multizone_sim

# %%
mc = ModelComparer(["fiducial", "lateburst", "analytic_lateburst"], labels=["fiducial", "lateburst", "analytic lateburst"])

# %% [markdown]
# # Mean abundance star tracks

# %%
fig, ax = plt.subplots()
ax.set_ylim(-0.5, 0.5)
mc.plot_mean_stars("[o/h]", "[c/o]", xlim=(-0.6, 0.4), filename="cooh_lateburst", ax=ax)
# Out:
# saved

# %%
mc.plot_all_mean_stars(filename="stars_sfh")
# Out:
# saving

# %% [markdown]
# # Gas phase tracks

# %%
mc.plot_gas("[o/h]", "[c/o]")
# mc.plot_gas("[fe/h]", "[c/n]")

# %% [markdown]
# # MDFs

# %%
mc.plot_mdf("[o/h]")
mc.plot_mdf("[n/o]")
mc.plot_mdf("[c/n]")
mc.plot_mdf("[c/o]")

# %% [markdown]
# # Stars

# %%
mc.plot_stars("age", "[c/o]", c="R_origin", xlim=(0, 10))

# %%
mc.plot_stars("[o/h]", "[c/o]", c="R_origin", c_label="R", xlim=(-0.4, 0.4), ylim=(-0.5, 0.2), solar_neighborhood=True)

# %%
mc.plot_stars("[o/fe]", "[c/o]", c="age", c_label="age", xlim=(-0.25, 0.25), ylim=(-0.2, 0.3), solar_neighborhood=True)

# %% [markdown]
# # Gas phase tracks

# %%
mc.plot_model_fixed_t(ylim=(-1, 0.2))

# %%
for model in mc.models.keys():
    plt.xlim(-0.1, 0.5)
    mc.plot_model_fixed_r(model, "[o/fe]", "[c/o]")

# %%
mc.plot_model_fixed_r("fiducial", "[o/fe]", "[c/o]", "coofe_fixed_r_fiducial")
