# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
import matplotlib.pyplot as plt

# %%
import analysis_scripts.apogee_analysis as aah
import analysis_scripts.gas_phase_data as gap
import analysis_scripts.rc_params

# %%
gap.plot_all("[o/h]", "[c/o]")
aah.plot_stars("[o/h]", "[c/o]")
aah.plot_mean_v21("[o/h]", "[c/o]")
plt.xlabel("[O/H]")
plt.ylabel("[C/O]")
plt.ylim(-1, 0.5)
plt.xlim(-1, 0.6)
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (-1.0, 0.6)
