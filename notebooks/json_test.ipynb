# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False

# %%
import vice
import sys
import matplotlib.pyplot as plt
sys.path.append("..") # very hacky way of adding surp

from surp.analysis_scripts import vice_to_json
from surp.analysis_scripts import vice_utils
import surp.model_scripts.multizone_sim
import surp
from surp.model_scripts import multizone_sim
import dill
import multizone_sim

# %%
cd ~/surp
# Out:
# /users/PAS2232/aeyobd/surp

# %%
from surp.analysis_scripts.vice_model import vice_model

# %%
model = vice_model("cristallo11_f0.1_Z0.444_eta1.0_v0.1.3_lateburst.json")

# %%
model.plot_stars("[o/fe]", "[c/o]", c="age")
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/seaborn/distributions.py:1213: UserWarning: The following kwargs were not used by contour: 'xlim'
#   **contour_kws,

# %%
model.plot_mean_stars("[o/h]", "[c/o]")
plt.xlim(-0.6, 0.6)
plt.ylim(-0.5, 0.5)
# Out:
# (-0.5, 0.5)

# %%
model.plot_mean_stars("[o/fe]", "[c/o]")
plt.xlim(-0.6, 0.6)
plt.ylim(-0.5, 0.5)
# Out:
# (-0.5, 0.5)

# %%
model.plot_mean_coofe()

# %%
model.plot_annulus_at_t("[o/fe]", "[c/o]", 10, dt=0.2)

# %%
model = vice_model("output/cristallo11_f0.1_Z0.444_eta1.0_v0.1.3_lateburst.json")
