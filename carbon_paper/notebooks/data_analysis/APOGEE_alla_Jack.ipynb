# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from astropy.io import fits

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import pickle
import numpy as np
import pandas as pd
import vice
import surp.analysis.apogee_analysis as aah
import seaborn as sns

from astropy.table import Table
import surp.analysis.plotting_utils as plotting
import astropy as ap
import astropy.units as u
# Out:
# modified solar abundances via mag++22

# %%
import arya

# %%
file_name = "../../data/allStar-dr17-synspec_rev1.fits.1"

# %%
ff = fits.open(file_name, mmap=True)
da = ff[1].data
ff.close()

# %% [markdown]
# 'ancillary young embedded cluster member', 'ancillary emission line star', 'MIR-detected candidate cluster member (ancillary)',
#
# APOGEE2_Target3: 'Selected as part of the EB program', 'Selected as part of the young cluster study (IN-SYNC)', 'Ancillary W3/4/5 star forming complex'
#
#
#
# Finally, I restrict to the given Log(g)-Teff domain:
# log(g) ≥ 3.5
# log(g) ≤ 0.004 ∗ (𝑇eff ) − 15.7
# log(g) ≤ 0.00070588 ∗ (𝑇eff ) + 0.358836
# log(g) ≤ −0.0015 ∗ (𝑇eff ) + 12.05
# log(g) ≥ 0.0012 ∗ (𝑇eff ) − 2.8

# %%
apogee_target2 = 1<<17 #APOGEE_MIRCLUSTER_STAR
apogee_target2 ^= 1<<15 #APOGEE_EMISSION_STAR  emission line stars
apogee_target2 ^= 1<<13 #APOGEE_EMBEDDEDCLUSTER_STAR embedded cluster

# %%
apogee2_target3 = 1<<5 # young cluster (IN-SYNC)
apogee2_target3 ^= 1<<18 #APOGEE2_W345
apogee2_target3 ^= 1<<1 # EB planet

# %%
mask = (da["APOGEE2_TARGET3"] & apogee2_target3) == 0
print(sum(mask))
mask &= (da["APOGEE_TARGET2"] & apogee_target2) == 0
print(sum(mask))
# Out:
# 721431
# 717682

# %%
apogee_aspcapflag = 1<<23 # starbad
apogee_aspcapflag ^= 1<<31 # no_aspcap_result

mask &= (da["ASPCAPFLAG"] & apogee_aspcapflag) == 0
print(sum(mask))
mask &= da["EXTRATARG"] == 0
# Out:
# 680297

# %%
print(sum(mask))
# Out:
# 364342

# %%
logg = da["LOGG"]
teff = da["TEFF"]

mask &= logg >= 3.5
mask &= logg <= 0.004*teff - 15.7
mask &= logg <= 0.000706*teff + 0.36
mask &= logg <= -0.0015 * teff + 12.05
mask &= logg >= 0.0012*teff - 2.8

# %%
sum(mask)
# Out:
# 9256

# %%
# cuts in W+19
filtered = da[mask]
# del da

# %% [markdown]
# Jack's coordinates are
#
# - (3.5, 4800)
# - (3.8, 4875)
# - (4.1, 5300)
# - (3.8, 5500)
# - (3.5, 5250)

# %%
coords = [
    (3.5, 4800),
    (3.8, 4875),
    (4.1, 5300),
    (3.8, 5500),
    (3.5, 5250),
    (3.5, 4800)
]
y = [c[0] for c in coords]
x = [c[1] for c in coords]

# %%
plt.figure(figsize=(10/3, 10/3), rasterized=True, dpi=350)
_, _, _, img = plt.hist2d(da["TEFF"], da["LOGG"], range=((3000, 7000), (2, 5)), bins=100, norm="log", cmin=3, cmap=arya.style.get_cmap(to_white=True, reverse=True))
img.set_edgecolor("none")


plt.plot(x, y, lw=2, color="k")

plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.xlabel("$T_{\\rm eff}$ (K)")
plt.ylabel("$\\log$ g")
plt.savefig("logg_jack.pdf")

# %%
df = pd.DataFrame(filtered.tolist(), columns = [c.name for c in filtered.columns])

# %%
filename = "../../data/apogee_astroNN-DR17.fits"

ff = fits.open(filename, mmap=True)
astroNN = ff[1].data

df_aNN = pd.DataFrame(dict(
    R_gal = astroNN["galr"].byteswap().newbyteorder(),
    z_gal = astroNN["galz"].byteswap().newbyteorder()),
    index = astroNN["APOGEE_ID"].byteswap().newbyteorder())

# %%
joined = df.join(df_aNN, on="APOGEE_ID")

# %%
sns.kdeplot(joined.R_gal)
# Out:
# <Axes: xlabel='R_gal', ylabel='Density'>

# %%
df.to_csv("../../data/subgiants.csv")

# %%
pd.read_csv("../../data/subgiants.csv")
# Out:
# /tmp/ipykernel_18530/1590072509.py:1: DtypeWarning: Columns (126) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("../../data/subgiants.csv")
#        Unnamed: 0                                 FILE           APOGEE_ID
# 0               0  apStar-dr17-2M00002185+1459100.fits  2M00002185+1459100  \
# 1               1  apStar-dr17-2M00004159+6505249.fits  2M00004159+6505249
# 2               2  apStar-dr17-2M00004251+5643075.fits  2M00004251+5643075
# 3               3  apStar-dr17-2M00005728+6958488.fits  2M00005728+6958488
# 4               4  apStar-dr17-2M00012854+7021553.fits  2M00012854+7021553
# ...           ...                                  ...                 ...
# 16391       16391  apStar-dr17-2M23582628+5524124.fits  2M23582628+5524124
# 16392       16392  apStar-dr17-2M23582727+5606296.fits  2M23582727+5606296
# 16393       16393  apStar-dr17-2M23590547+1514580.fits  2M23590547+1514580
# 16394       16394  asStar-dr17-2M23594577-7351233.fits  2M23594577-7351233
# 16395       16395  apStar-dr17-2M23594945+1445256.fits  2M23594945+1445256
#
#                                    TARGET_ID
# 0       apo25m.107-46_MGA.2M00002185+1459100  \
# 1           apo25m.117+01.2M00004159+6505249
# 2      apo25m.NGC7789_btx.2M00004251+5643075
# 3           apo25m.120+08.2M00005728+6958488
# 4           apo25m.120+08.2M00012854+7021553
# ...                                      ...
# 16391        apo25m.N7789.2M23582628+5524124
# 16392        apo25m.N7789.2M23582727+5606296
# 16393   apo25m.107-46_MGA.2M23590547+1514580
# 16394        lco25m.SMC12.2M23594577-7351233
# 16395       apo25m.105-45.2M23594945+1445256
#
#                                                APSTAR_ID
# 0      apogee.apo25m.stars.107-46_MGA.2M00002185+1459100  \
# 1          apogee.apo25m.stars.117+01.2M00004159+6505249
# 2      apogee.apo25m.stars.NGC7789_btx.2M00004251+564...
# 3          apogee.apo25m.stars.120+08.2M00005728+6958488
# 4          apogee.apo25m.stars.120+08.2M00012854+7021553
# ...                                                  ...
# 16391       apogee.apo25m.stars.N7789.2M23582628+5524124
# 16392       apogee.apo25m.stars.N7789.2M23582727+5606296
# 16393  apogee.apo25m.stars.107-46_MGA.2M23590547+1514580
# 16394       apogee.lco25m.stars.SMC12.2M23594577-7351233
# 16395      apogee.apo25m.stars.105-45.2M23594945+1445256
#
#                                                ASPCAP_ID TELESCOPE
# 0      apogee.apo25m.synspec_fix.107-46_MGA.2M0000218...    apo25m  \
# 1      apogee.apo25m.synspec_fix.117+01.2M00004159+65...    apo25m
# 2      apogee.apo25m.synspec_fix.NGC7789_btx.2M000042...    apo25m
# 3      apogee.apo25m.synspec_fix.120+08.2M00005728+69...    apo25m
# 4      apogee.apo25m.synspec_fix.120+08.2M00012854+70...    apo25m
# ...                                                  ...       ...
# 16391  apogee.apo25m.synspec_fix.N7789.2M23582628+552...    apo25m
# 16392  apogee.apo25m.synspec_fix.N7789.2M23582727+560...    apo25m
# 16393  apogee.apo25m.synspec_fix.107-46_MGA.2M2359054...    apo25m
# 16394  apogee.lco25m.synspec_fix.SMC12.2M23594577-735...    lco25m
# 16395  apogee.apo25m.synspec_fix.105-45.2M23594945+14...    apo25m
#
#        LOCATION_ID        FIELD ALT_ID  ...       O_H      MG_H       C_O
# 0             2897   107-46_MGA   none  ... -0.311139 -0.176264 -0.046217  \
# 1             4591       117+01   none  ...  0.458603  0.533275 -0.053378
# 2             5922  NGC7789_btx   none  ...  0.326035  0.301142  0.005436
# 3             4120       120+08   none  ... -0.007019  0.154887  0.074323
# 4             4120       120+08   none  ...  0.179625  0.099637 -0.218940
# ...            ...          ...    ...  ...       ...       ...       ...
# 16391         4264        N7789   none  ...  0.116609  0.067715 -0.071868
# 16392         4264        N7789   none  ... -0.492633 -0.480111 -0.097907
# 16393         2897   107-46_MGA   none  ...  0.187935  0.193917 -0.090839
# 16394         7218        SMC12   none  ...  0.204993  0.127543 -0.225732
# 16395         4548       105-45   none  ... -0.053367 -0.105177 -0.290739
#
#            C_MG       C_H       C_N       N_H       N_O      N_MG  high_alpha
# 0     -0.181092 -0.357356  0.091994 -0.449350 -0.138211 -0.273086       False
# 1     -0.128050  0.405225 -0.218545  0.623770  0.165167  0.090495       False
# 2      0.030329  0.331471 -0.221919  0.553390  0.227355  0.252248       False
# 3     -0.087583  0.067304  0.299130 -0.231826 -0.224807 -0.386713        True
# 4     -0.138952 -0.039315 -0.395929  0.356614  0.176989  0.256977       False
# ...         ...       ...       ...       ...       ...       ...         ...
# 16391 -0.022974  0.044741 -0.102652  0.147393  0.030784  0.079678       False
# 16392 -0.110429 -0.590540  0.359780 -0.950320 -0.457687 -0.470209       False
# 16393 -0.096821  0.097096 -0.064801  0.161897 -0.026038 -0.032020       False
# 16394 -0.148282 -0.020739 -0.041339  0.020600 -0.184393 -0.106943        True
# 16395 -0.238929 -0.344106  0.236904 -0.581010 -0.527643 -0.475833        True
#
# [16396 rows x 249 columns]

# %% [markdown]
# # Start here

# %%
df = aah.subgiants()
v21 = aah.vincenzo2021()
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
len(df)
# Out:
# 16396

# %%
len(v21)
# Out:
# 4875

# %%
import seaborn as sns

# %%
sns.kdeplot(df.R_gal)
plt.xlabel("R ga")
plt.xlim(5, 11)
# Out:
# (5.0, 11.0)

# %%
plotting.density_scatter(df.R_gal, df.z, xlim=(6, 9), ylim=(-1, 1), n_bins=50)
plt.xlabel("R gal (kpc)")
plt.ylabel("z (kpc)")
# Out:
# Text(0, 0.5, 'z (kpc)')

# %%
xlim = (-1, 0.6)

filt = ~df["high_alpha"]
plotting.density_scatter(df[filt]["MG_H"], df[filt]["C_MG"], xlim=xlim, ylim=(-0.5, 0.5))
plt.xlabel("[Mg/H]")
plt.ylabel("[C/Mg]")
aah.plot_v21_contour("[o/h]", "[c/o]")
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plotting.density_scatter(df["FE_H"], df["MG_FE"]);
plt.xlim(-0.8, 0.5)
plt.ylim(-0.2, 0.5)
# Out:
# (-0.2, 0.5)

# %%
plt.scatter(df["FE_H"], df["MG_FE"], c=df["high_alpha"], s=0.1, alpha=0.5)
plt.xlabel("fe/h")
plt.ylabel('o/fe')
plt.xlim(-1, 0.6)
plt.ylim(-0.2, 0.5)
# Out:
# (-0.2, 0.5)

# %% [markdown]
# Plot of the o/fe-fe/h bimodality in apogee data

# %%
import sys

# %%
sys.path.append("..")

# %%
np.isnan
# Out:
# <ufunc 'isnan'>

# %%
import apogee_analysis as aah
from vice_to_pickle import plot_mean_track
# Out:
# ../VICE/migration/src/plots/env.py:42: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams["text.latex.preamble"] = [r"\usepackage{amsmath}"]

# %%
plotting.density_scatter(df["MG_H"], df["O_H"] - df["MG_H"], xlim=(-0.5, 0.5), ylim=(-0.4, 0.3));
plot_mean_track(df["MG_H"], df["O_H"] - df["MG_H"], xlim=(-0.5, 0.5), dropna=True, color="k", lw=3);

plt.xlabel("[Mg/H]")
plt.ylabel("[O/Mg]")
# Out:
# Text(0, 0.5, '[O/Mg]')

# %%
plt.scatter(df["MG_H"], df["C_MG"], s=0.1, c=df["high_alpha"])
ha = df[df["high_alpha"]]
la = df[~df["high_alpha"]]
plt.xlabel("[O/H]")
plt.ylabel("[C/O]")
plt.xlim(-0.6, 0.6)
plt.ylim(-0.4, 0.2)
aah.plot_mean_v21("[o/h]", "[c/o]")
plot_mean_track(ha["MG_H"], ha["C_MG"], bins=20, xlim=(-0.5, 0.5), dropna=True)
plot_mean_track(la["MG_H"], la["C_MG"], bins=20, xlim=(-0.5, 0.5), dropna=True)
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.6/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# (array([-0.07262308, -0.05965643, -0.07320338, -0.07674088, -0.08773011,
#         -0.09398162, -0.09644179, -0.09895688, -0.09707031, -0.09925365,
#         -0.08797876, -0.07657256, -0.06648114, -0.05776557, -0.04819869,
#         -0.02969707, -0.01343342, -0.01317402, -0.01615176, -0.01592566]),
#  array([-0.5 , -0.45, -0.4 , -0.35, -0.3 , -0.25, -0.2 , -0.15, -0.1 ,
#         -0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,
#          0.4 ,  0.45,  0.5 ]),
#  array([ 34.,  55., 123., 222., 347., 472., 550., 688., 850., 900., 943.,
#         996., 950., 842., 643., 583., 506., 375., 150.,  41.]))

# %%
import scipy

# %%
for o0 in [-0.2, -0.1, 0, 0.1, 0.2, 0.3, 0.4]:
    sl = df["O_H"] > o0-0.05
    sl &= df["O_H"] < o0 + 0.05
    plt.scatter(df[sl]["O_FE"], df[sl]["C_O"], s=0.1, color="k")
    plot_mean_track(df[sl]["O_FE"], df[sl]["C_O"], label="o", shade_width=True, err_mean=True, bins=20, xlim=(-0.3, 0.3))
    plt.xlabel("[O/Fe]")
    plt.ylabel("[C/O]")

    sl = df["MG_H"] > o0-0.05
    sl &= df["MG_H"] < o0 + 0.05

    plot_mean_track(df[sl]["MG_FE"], df[sl]["C_MG"], label="mg")

    sl = v21["[o/h]"] > o0-0.05
    sl &= v21["[o/h]"] < o0 + 0.05

    plot_mean_track(v21[sl]["[o/fe]"], v21[sl]["[c/o]"]-0.1, label="v21")

    plt.xlim(-0.4, 0.4)
    plt.ylim(-0.6, 0.4)
    plt.legend()
    plt.title("[O/H]= %s" % o0)
    plt.show()
# Out:
# /users/PAS2232/aeyobd/surp/vice_to_pickle.py:400: RuntimeWarning: invalid value encountered in true_divide
#   dy = std / np.sqrt(nums)
# /users/PAS2232/aeyobd/surp/vice_to_pickle.py:400: RuntimeWarning: invalid value encountered in true_divide
#   dy = std / np.sqrt(nums)
# /users/PAS2232/aeyobd/surp/vice_to_pickle.py:400: RuntimeWarning: invalid value encountered in true_divide
#   dy = std / np.sqrt(nums)
# /users/PAS2232/aeyobd/surp/vice_to_pickle.py:400: RuntimeWarning: invalid value encountered in true_divide
#   dy = std / np.sqrt(nums)
# /users/PAS2232/aeyobd/surp/vice_to_pickle.py:400: RuntimeWarning: invalid value encountered in true_divide
#   dy = std / np.sqrt(nums)
# /users/PAS2232/aeyobd/surp/vice_to_pickle.py:400: RuntimeWarning: invalid value encountered in true_divide
#   dy = std / np.sqrt(nums)

# %%
plot_mean_track?
# Out:
# Signature:
# plot_mean_track(
#     x_vals,
#     y_vals,
#     bins=30,
#     xlim=None,
#     shade_width=False,
#     err_mean=False,
#     ax=None,
#     dropna=False,
#     **kwargs,
# )
# Docstring:
# Plots the mean of the data as a line
# with a shaded region representing the standard deviation
#
# Parameters
# ----------
#
# x_vals: np.array like
#     The x values of the data
#
# y_vals: np.array like
# bins: ``int`` [default: 50]
#     The number of bins to bin the data by
# xlim: ``(int, int)`` [default: None]
#     The limits of the bins of the data
#     if None, uses the minimum and maximum values
# err_mean: ``bool`` [default: False]
#     If true, plots the error of the mean instead
#     of the standard deviation for the shaded regions
# File:      ~/surp/vice_to_pickle.py
# Type:      function

# %%
for o0 in [-0.2, 0, 0.2]:
    sl = df["MG_H"] > o0-0.05
    sl &= df["MG_H"] < o0 + 0.05

    plot_mean_track(df[sl]["MG_FE"], df[sl]["C_MG"], label="%1.1f" % o0, xlim=(-0.2, 0.5))



plt.legend()

plt.xlabel("[O/Fe]")
plt.ylabel("[C/O]")
# Out:
# Text(0, 0.5, '[C/O]')

# %%
for o0 in [-0.2, 0, 0.2]:
    sl = v21["[o/h]"] > o0-0.05
    sl &= v21["[c/o]"] < o0 + 0.05

    plot_mean_track(v21[sl]["[o/fe]"], v21[sl]["[c/o]"], label="%1.1f" % o0, xlim=(-0.2, 0.5))



plt.legend()

plt.xlabel("[O/Fe]")
plt.ylabel("[C/O]")
# Out:
# Text(0, 0.5, '[C/O]')

# %%
for o0 in [-0.2, 0, 0.2]:
    sl = df["MG_H"] > o0-0.05
    sl &= df["MG_H"] < o0 + 0.05

    plt.scatter(df[sl]["MG_FE"], df[sl]["C_MG"], label="%1.1f" % o0, s=0.5)


plt.xlim(-0.4, 0.5)
plt.ylim(-0.6, 0.4)
plt.legend()
plt.title("[O/H]= %s" % o0)

plt.xlabel("[O/Fe]")
plt.ylabel("[C/O]")
# Out:
# Text(0, 0.5, '[C/O]')

# %%
plt.scatter(df["MG_FE"], df["C_MG"], c=df["MG_H"], s=1)
plt.colorbar()

# %%
sl = df["MG_H"] > o0-0.05
sl &= df["MG_H"] < o0 + 0.05
sl &= ~df["high_alpha"]
plt.scatter(df[sl]["MG_FE"], df[sl]["C_MG"], s=0.1)
plt.xlabel("[Mg/Fe]")
plt.ylabel("[C/Mg]")
plt.xlim(-0.4, 0.4)
plt.ylim(-0.6, 0.4)
plot_mean_track(df[sl]["MG_FE"], df[sl]["C_MG"])
# Out:
# (array([-0.0344885 ,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.075701  ,         nan,  0.015268  ,
#         -0.02157549,  0.050641  ,  0.00227482,  0.00120336,  0.01515766,
#          0.00657383, -0.04749849, -0.01726284, -0.0318123 , -0.00141939,
#         -0.01238043, -0.01767001, -0.01268865, -0.02970117, -0.02265091,
#         -0.03544594, -0.03173955, -0.04658423, -0.03431224, -0.04115676,
#         -0.04441861, -0.04052622, -0.04497969, -0.04535964, -0.05529534,
#         -0.06015299, -0.06476934, -0.0593204 , -0.07294861, -0.07626922,
#         -0.07003   , -0.07560289, -0.08475444, -0.09116492, -0.08208886,
#         -0.08617679, -0.08716039, -0.0885235 , -0.08110326, -0.08748305]),
#  array([-0.08370149, -0.07963602, -0.07557055, -0.07150508, -0.06743961,
#         -0.06337414, -0.05930867, -0.0552432 , -0.05117773, -0.04711226,
#         -0.04304679, -0.03898132, -0.03491585, -0.03085038, -0.02678491,
#         -0.02271944, -0.01865397, -0.0145885 , -0.01052303, -0.00645756,
#         -0.00239209,  0.00167338,  0.00573885,  0.00980432,  0.01386979,
#          0.01793526,  0.02200073,  0.0260662 ,  0.03013167,  0.03419714,
#          0.03826261,  0.04232808,  0.04639355,  0.05045902,  0.05452449,
#          0.05858996,  0.06265543,  0.0667209 ,  0.07078637,  0.07485184,
#          0.07891731,  0.08298278,  0.08704825,  0.09111372,  0.09517919,
#          0.09924466,  0.10331013,  0.1073756 ,  0.11144107,  0.11550654,
#          0.11957201]),
#  array([24, 45, 34, ..., 35, 40, 47]))

# %%
def plot_abundance_alpha(x="O_H", y="C_O", df=split, fig=None, ax=None, s=0.001):
    if fig is None or ax is None:
        fig, ax = plt.subplots()
        
    x_vals = bracket(df, *x.split("_"))
    y_vals = bracket(df, *y.split("_"))
    ax.scatter(x_vals[df.hi_alpha], y_vals[df.hi_alpha], label="low SNIa", alpha=1, s=s)
    ax.scatter(x_vals[~df.hi_alpha], y_vals[~df.hi_alpha], label="high SNIa", alpha=1, s=s)
    ax.legend(markerscale=0.1/s)
    ax.set_xlabel(x)
    ax.set_ylabel(y)

# %%
plot_abundance_alpha(y="N_O")

# %%
plot_abundance_alpha()
plt.show()

plot_abundance_alpha(y="N_O")
plt.show()

plot_abundance_alpha(y="C_N")
plt.show()

plot_abundance_alpha(y="MG_AL")

# %%
plot_abundance_alpha(x = "MG_H", y = "AL_H")

# %%
def plot_in_gal_region(x="O_H", y="C_O", xlabel=None, ylabel=None):
    fig, axs = plt.subplots(5, 3, sharex=True, sharey=True, figsize=(20,15))
    for j in range(5):
        R_min, R_max = [(1, 3), (3, 5), (5,7), (7,9), (9,11), (11,13)][j]
    

        for i in range(3):
            z_min, z_max = [(0, 0.5), (0.5, 1), (1, 2)][i]
            ax = axs[j][i]
            mask = split.R_gal > R_min
            mask &= split.R_gal < R_max
            mask &= split.abs_z > z_min
            mask &= split.abs_z < z_max
            
            # plotting.density_scatter(x[mask], y[mask], fig=fig, ax=ax)
            plot_abundance_alpha(x, y, df = split[mask], fig=fig, ax=ax, s=0.01)
            ax.set_xlabel("")
            ax.set_ylabel("")
            if j==0:
                ax.set(title="z =  %1.1f - %1.1f" % (z_min, z_max))
            if i == 0:
                ax.set_ylabel("R = %i - %i" %(R_min, R_max))
                

                
    fig.supxlabel("[%s/%s]" % tuple(x.split("_")))
    fig.supylabel("[%s/%s]" % tuple(y.split("_")))

# %%
plot_in_gal_region(x = "FE_H", y="O_FE")

# %%
plot_in_gal_region(y="C_N")

# %% [markdown]
# Plots of C/N vs O/H in different galactic regions

# %%
plot_in_gal_region(y="C_O")

# %%
plot_in_gal_region(y="N_O")

# %%
v21 = aah.vincenzo2021()
# Out:
# /home/daniel/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.scatter(v21["age"], v21["[o/h]"], s=1)

# %%
plt.scatter(v21["[o/h]"], v21["[c/o]"], s=0.1, alpha=0.2, label="V21")
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
plt.scatter(df["O_H"], df["C_O"], s=0.1, alpha=0.1, label="APOGEE")
plt.xlim(-1,0.7)
plt.ylim(-0.7, 0.6)
plt.legend(markerscale=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-279341c277af> in <module>
#       2 plt.xlabel("[o/h]")
#       3 plt.ylabel("[c/o]")
# ----> 4 plt.scatter(df["O_H"], df["C_O"], s=0.1, alpha=0.1, label="APOGEE")
#       5 plt.xlim(-1,0.7)
#       6 plt.ylim(-0.7, 0.6)
#
# NameError: name 'df' is not defined

# %%
plt.hist(df["VSINI"][df["VSINI"] > 0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-925887f76bc4> in <module>
# ----> 1 plt.hist(df["VSINI"][df["VSINI"] > 0])
#
# NameError: name 'df' is not defined

# %%
plt.scatter(v21["[o/h]"], v21["[c/o]"], s=1)
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
# Out:
# Text(0, 0.5, '[c/o]')

# %%
plt.scatter(v21["age"], v21["[c/n]"], s=1, c=v21["[o/h]"], cmap="inferno")
plt.xlim(0, 20)
plt.colorbar(label="[o/h]")
plt.xlabel("Age/Gyr")
plt.ylabel("[C/N]")
# Out:
# Text(0, 0.5, '[C/N]')

# %%
plt.hist(v21["[c/h]"], 50)
plt.xlabel("[c/h]")
plt.show()

plt.hist(v21["[c/o]"], 50)
plt.xlabel("[c/o]")
plt.show()

plt.hist(v21["[c/n]"], 50)
plt.xlabel("[c/n]")
# Out:
# Text(0.5, 0, '[c/n]')

# %%
# rom skillman 2020, table 2
# https://ui.adsabs.harvard.edu/abs/2020ApJ...894..138S/abstract

aah.plot_skillman20_cnoh()
plt.xlabel("[o/h]")
plt.ylabel("[c/n]")
plt.show()
aah.plot_skillman20_cooh()
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
# Out:
# Text(0, 0.5, '[c/o]')

# %%
plt.scatter(v21["[c/o]"] , v21["[o/h]"], c=v21["age"], vmin=0, s=1)
plt.colorbar(label="age/Gyr")
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
# Out:
# Text(0, 0.5, '[c/o]')

# %%
plt.scatter(v21["[c/o]"] , v21["[o/h]"], c=v21["[o/fe]"], vmin=0, s=1)
plt.colorbar(label="age/Gyr")
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '[o/fe]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-1a987fa92e0a> in <module>
# ----> 1 plt.scatter(v21["[c/o]"] , v21["[o/h]"], c=v21["[o/fe]"], vmin=0, s=1)
#       2 plt.colorbar(label="age/Gyr")
#       3 plt.xlabel("[o/h]")
#       4 plt.ylabel("[c/o]")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '[o/fe]'

# %%
v21
# Out:
#        [mg/fe]    [fe/h]    [c/fe]    [n/fe]     [c/h]     [n/h]   age  \
# 0     0.247532 -0.292042  0.158510  0.052401 -0.069385 -0.436210  10.1
# 1     0.042202  0.049127 -0.016018  0.197207  0.113361  0.006940   8.5
# 2     0.290692 -0.351292  0.153900  0.091762 -0.122959 -0.484260   8.8
# 3     0.027853 -0.178222 -0.012749  0.202450 -0.069914 -0.290230   3.6
# 4     0.257632 -0.211932  0.168140  0.196530  0.010191 -0.179516  13.7
# ...        ...       ...       ...       ...       ...       ...   ...
# 5071  0.054724 -0.221732 -0.112970  0.360880 -0.153254 -0.250104   1.6
# 5072  0.063233  0.008628 -0.007638  0.167090  0.081244 -0.063674   9.1
# 5073  0.109576  0.281778  0.107047  0.196150  0.447155  0.301935  11.1
# 5074 -0.041400  0.154678 -0.060001  0.448730  0.266917  0.225569   1.0
# 5075  0.069604 -0.034680 -0.007604  0.140335  0.069894 -0.194662   4.1
#
#          [c/n]     [o/h]     [n/o]     [c/o]   [c+n/h]   [c+n/o]
# 0     0.376624 -0.079585 -0.356624  0.010201 -0.129447 -0.049862
# 1     0.116219  0.073644 -0.066703  0.039717  0.091440  0.017796
# 2     0.371100 -0.169290 -0.314970  0.046331 -0.182400 -0.013110
# 3     0.230115 -0.128322 -0.161908  0.058408 -0.110926  0.017395
# 4     0.199505  0.014441 -0.193956 -0.004250 -0.026094 -0.040535
# ...        ...       ...       ...       ...       ...       ...
# 5071  0.106649 -0.229760 -0.020344  0.076506 -0.173374  0.056385
# 5072  0.154717  0.041089 -0.104763  0.040155  0.052400  0.011311
# 5073  0.155018  0.364991 -0.063056  0.082164  0.418258  0.053267
# 5074  0.051146  0.167322  0.058247  0.099595  0.257891  0.090569
# 5075  0.274354  0.026158 -0.220820  0.043736  0.022531 -0.003627
#
# [4875 rows x 13 columns]

# %%
plt.scatter(v21["[fe/h]"], v21["[mg/fe]"], s=1)

# %%
plt.scatter(v21["[o/h]"], v21["[c/o]"], c=v21["[mg/fe]"], s=1, alpha=0.2)
plt.xlabel("[o/h]")
plt.ylabel("[c/o]")
plt.colorbar(label="[mg/fe]")

# %%
plt.scatter(v21["age"], v21["[cn/h]"] - v21["[o/h]"], c=v21["[o/h]"], s=1, alpha=0.5)
plt.xlabel("age")
plt.ylabel("[c+n/o]")
plt.colorbar(label="[o/h]")
plt.xlim(0, 15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '[cn/h]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-ac72ffd09323> in <module>
# ----> 1 plt.scatter(v21["age"], v21["[cn/h]"] - v21["[o/h]"], c=v21["[o/h]"], s=1, alpha=0.5)
#       2 plt.xlabel("age")
#       3 plt.ylabel("[c+n/o]")
#       4 plt.colorbar(label="[o/h]")
#       5 plt.xlim(0, 15)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '[cn/h]'

# %%
plt.scatter(v21["[o/h]"], v21["[c-n/h]"] - v21["[o/h]"], c=v21["age"], vmin=0, vmax=14, s=1, alpha=0.5)
plt.xlabel("[o/h]")
plt.ylabel("[c-n/o]")
plt.colorbar(label="age/Gyr")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '[c-n/h]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f27f0f1b0072> in <module>
# ----> 1 plt.scatter(v21["[o/h]"], v21["[c-n/h]"] - v21["[o/h]"], c=v21["age"], vmin=0, vmax=14, s=1, alpha=0.5)
#       2 plt.xlabel("[o/h]")
#       3 plt.ylabel("[c-n/o]")
#       4 plt.colorbar(label="age/Gyr")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '[c-n/h]'

# %%
plt.scatter(v21["age"], v21["[c-n/h]"] - v21["[o/h]"], c=v21["[o/h]"], s=1, alpha=0.5)
plt.xlabel("age")
plt.ylabel("[c-n/o]")
plt.xlim(0, 15)
plt.colorbar(label="[o/h]")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '[c-n/h]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-af33d7bb0031> in <module>
# ----> 1 plt.scatter(v21["age"], v21["[c-n/h]"] - v21["[o/h]"], c=v21["[o/h]"], s=1, alpha=0.5)
#       2 plt.xlabel("age")
#       3 plt.ylabel("[c-n/o]")
#       4 plt.xlim(0, 15)
#       5 plt.colorbar(label="[o/h]")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '[c-n/h]'

# %% [markdown]
# # Quantifying scatter

# %%
plt.hist(df["O_FE_ERR"], 100);

# %%
plt.hist(df["O_FE_ERR"], 1000);
plt.xlim(0, 1)

# %%
plt.hist(df["FE_H_ERR"], 100);

# %% [markdown]
# # MultiProcess Model
#
# Trying to apply methods from W+19 to AGB star yields.
