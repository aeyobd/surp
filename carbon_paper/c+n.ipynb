# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
from dataclasses import dataclass
import pandas as pd
import vice
import seaborn as sns


from scipy.stats import binned_statistic
from scipy.integrate import quad
from scipy.interpolate import interp1d, interp2d, CubicSpline
from scipy.optimize import curve_fit
import scipy

from statsmodels.distributions import ECDF

# %%
import surp
from surp.analysis.vice_model import vice_model
import surp.analysis.apogee_analysis as aah
from surp.analysis import plotting_utils as pluto

subgiants = aah.subgiants

import arya
arya.style.set_size((10/3, 10/3))

# %%
data = pd.read_csv("../data/apogee_cartography.csv", index_col=0)
# Out:
# /tmp/slurmtmp.23837943/ipykernel_254285/3603862041.py:1: DtypeWarning: Columns (126) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/apogee_cartography.csv", index_col=0)

# %%
df = data[~data["high_alpha"]].copy()

# %%
# Grab cdf
cdf = ECDF(df.R_gal)

bins = np.arange(0, 20, 0.1)

zones = np.arange(0, 200)
Rs = (0.5 + zones)/10
table = pd.DataFrame({"zone": zones, "R": Rs, "cdf": cdf(bins + 0.1)/cdf(bins + 0.1)[-1]})

# %%
fiducial = vice_model("../out/C11_f0.2_rand_walk.json").stars_unsampled

# %%
fiducial["[c/h]"] = fiducial["[c/o]"] + fiducial["[o/h]"]
fiducial["[n/h]"] = fiducial["[n/o]"] + fiducial["[o/h]"]

fiducial["[cn/h]"] = surp.analysis.cpn(fiducial["[c/h]"], fiducial["[n/h]"])
fiducial["[cn/o]"] = fiducial["[cn/h]"] - fiducial["[o/h]"] + 0.075

# %% [markdown]
# # Create matching sample

# %%
num = 19000

sample = pd.DataFrame(columns=fiducial.columns)
for _ in range(num):
    star = surp.simulation.vice_to_json.rand_star(fiducial, table)
    sample = pd.concat((sample, star), ignore_index=True)

# %%
sns.kdeplot(sample.r_final, label="model")
sns.kdeplot(df.R_gal, label="data")
# Out:
# <Axes: xlabel='r_final', ylabel='Density'>

# %%
arya.plotting.medianplot(df, x="MG_H", y="CN_MG", binsize=200, stat="median", errorbar="pi", label="APOGEE Giants")

arya.medianplot(sample, x="[o/h]", y="[cn/o]", stat="median", errorbar=None,
    aes="line", binsize=200, label="model")

                                        
plt.xlabel("[Mg/H]")
plt.ylabel("[C+N/Mg]")
plt.xlim(-0.7)
plt.ylim(-0.2, 0.1)


arya.Legend(color_only=True)

plt.savefig("c+n.pdf")

# %%
data_kwargs = dict(
    color="k", 
    stat="median",
    err_kwargs=dict(facecolor="k", alpha=0.3)
)

model_kwargs = dict(
    stat="median", errorbar=None,
    aes="line"
)

def zooh_models(models, labels, y="C_MG", sequential=False, **kwargs):
    kwargs = dict(binsize=500, **kwargs)
    
    N = len(models)
    if sequential:
        hm = arya.figure.colorbar.HueMap(clim=(0, len(models)))
    for i in range(N):
        name = labels[i]
        model = models[i]
        if sequential:
            color = hm(i)
        else:
            color=None
        arya.medianplot(model, x="[o/h]", y=translate_label(y), label=name, color=color, **model_kwargs, **kwargs)


    df = subgiants[~subgiants.high_alpha]
    
    arya.medianplot(df, x="MG_H", y=y, zorder=-2, **data_kwargs, **kwargs)
    
    
def zofeo_models(models, labels, y="C_MG", sequential=False, mg_0=0.1, w=0.05, **kwargs):
    kwargs = dict(binsize=150, **kwargs)

    N = len(models)

    if sequential:
        hm = arya.figure.colorbar.HueMap(clim=(0, len(models)))
    for i in range(N):
        model = models[i]
        filt = model["[o/h]"] > mg_0 - w
        filt &= model["[o/h]"] < mg_0 + w
        df = model[filt].copy()
        if sequential:
            color = hm(i)
        else:
            color=None
        arya.medianplot(df, x="[o/fe]", y=translate_label(y), label=labels[i], color=color, **model_kwargs, **kwargs)
    
    filt = subgiants["MG_H"] > mg_0 - w
    filt &= subgiants["MG_H"] < mg_0 + w
    df = subgiants[filt]

    arya.medianplot(df, x="MG_FE", y=y, **data_kwargs, **kwargs)

# %%
def names_to_models(names):
    return [find_model(name) for name in names]

# %%
def compare_cooh(names, labels, **kwargs):
    models = names_to_models(names)
    zooh_models(models, labels, **kwargs)
    arya.Legend(color_only=True)
    plt.xlabel("[Mg/H]")
    plt.ylabel("[C/Mg]")
    
    plt.ylim(-0.225, 0.025)
    plt.yticks(np.arange(-0.2, 0.0, 0.05))
    plt.xlim(-0.4, 0.35)

# %%
def compare_coofe(names, labels, legend=True, **kwargs):
    models = names_to_models(names)
    zofeo_models(models, labels, legend=legend, **kwargs)
    if legend:
        arya.Legend(color_only=True)
    plt.xlabel("[Mg/Fe]")
    plt.ylabel("[C/Mg]")
    
    #plt.ylim(-0.3, 0.0)
    #plt.xlim(-0.4, 0 )

# %%
fig, axs = plt.subplots(4, 2, figsize=(7, 10), sharex="col", sharey=True, gridspec_kw={"wspace": 0, "hspace": 0})



names = [
    "C11_f0.2_zeta0.05_rand_walk",
    "C11_f0.2_zeta0.1_rand_walk",
    "C11_f0.2_zeta0.15_rand_walk",
]
labels = [
    r"$\zeta^{\rm cc}=0.05$", 
    r"$\zeta^{\rm cc}=0.1$", 
    r"$\zeta^{\rm cc}=0.15$"
]

plt.sca(axs[0][0])
compare_cooh(names, labels, sequential=True)
plt.sca(axs[0][1])
compare_coofe(names, labels, sequential=True, legend=False)


names = [    
    "C11_f0.2_rand_walk",
    "K10_f0.2_rand_walk",
    "V13_f0.2_rand_walk",
    "K16_f0.2_rand_walk",
  ]

labels = ["C11", "K10", "V13", "K16"]
plt.sca(axs[1][0])
compare_cooh(names, labels)
arya.Legend(loc=2, color_only=True)
plt.sca(axs[1][1])
compare_coofe(names, labels, legend=False)


names = [    
    "C11_f0.05_rand_walk",
    "C11_f0.2_rand_walk",
    "C11_f0.4_rand_walk",
  ]
labels = ["$f=0.05$", "$f=0.2$", "$f=0.4$"]
plt.sca(axs[2][0])
compare_cooh(names, labels, sequential=True)
plt.sca(axs[2][1])
compare_coofe(names, labels, sequential=True, legend=False)



names = [
    "C11_f0.2_rand_walk",
    "C11_f0.2_lateburst1_rand_walk",
    "C11_f0.2_eta0.5_rand_walk"
        ]

labels=["fiducial", "lateburst", r"$y_X\rightarrow y_X/2$"]
plt.sca(axs[3][0])
compare_cooh(names, labels)
arya.Legend(loc="lower right", color_only=True)
plt.sca(axs[3][1])
compare_coofe(names, labels, legend=False)


plt.savefig("all_p1.pdf")

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 5), sharex="col", sharey="row", gridspec_kw={"wspace": 0, "hspace": 0})



names = [
    "C11_f0.2_rand_walk",
    "C11_f0.3_rand_walk_Fe1.2",
    "C11_m1.5_f0.1_rand_walk",
        ]

labels=["fiducial", "higher ia/agb", "lower mass/agb"]

plt.sca(axs[0][0])
compare_cooh(names, labels)
arya.Legend(loc="lower right", color_only=True)
plt.sca(axs[0][1])
compare_coofe(names, labels, legend=False)



names = ["C11_f0.2_rand_walk"]
labels = ["nitrogen"]

plt.sca(axs[1][0])
models = names_to_models(names)
zooh_models(models, labels, y="N_MG")
plt.ylabel("[N/Mg]")
arya.Legend(loc="lower right", color_only=True)
plt.xlabel("[Mg/H]")
plt.ylim(-0.4, 0.2)

plt.sca(axs[1][1])
zofeo_models(models, labels, y="N_MG", legend=False)
plt.xlabel("[Mg/Fe]")

plt.savefig("all_p2.pdf")

# %%
names = ["C11_f0.2_rand_walk_an1.0",
        ]
labels = ["", "f"]


fig, axs = plt.subplots(1, 2, sharey=True, gridspec_kw=dict(wspace=0), figsize=(7, 10/3))

plt.sca(axs[0])

models = names_to_models(names)
zooh_models(models, labels, y="N_MG")

plt.xlabel("[Mg/H]")
plt.ylabel("[N/Mg]")
plt.xlim(-0.4)

plt.sca(axs[1])

models = names_to_models(names)
zofeo_models(models, labels, y="N_MG")

plt.xlabel("[Fe/Mg]")
plt.ylabel("[N/Mg]")

plt.ylim(-0.5, 0.2)

plt.savefig("nitrogen.pdf")

# %%
names = ["C11_f0.2_rand_walk",
         "C11_f0.2_rand_walk_an0.333",
         "C11_f0.2_rand_walk_an0.66",
         "C11_f0.2_rand_walk_an0.8",
        "C11_f0.2_rand_walk_an1.0"
        ]
labels = [""]


fig, axs = plt.subplots(1, 2, sharey=True, gridspec_kw=dict(wspace=0), figsize=(7, 10/3))

plt.sca(axs[0])

models = names_to_models(names)
zooh_models(models, labels, y="N_MG")

plt.xlabel("[Mg/H]")
plt.ylabel("[N/Mg]")
plt.xlim(-0.4)

plt.sca(axs[1])

models = names_to_models(names)
zofeo_models(models, labels, y="N_MG")

plt.xlabel("[Fe/Mg]")
plt.ylabel("[N/Mg]")

plt.ylim(-0.5, 0.2)

plt.savefig("nitrogen.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = [    
    "C11_f0.2_j8",
    "K10_f0.2_j8",
    "V13_f0.2_j8",
    "K16_f0.2_j8",]
labels = ["C11", "K10", "V13", "K16"]

compare_cooh(names, labels)
plt.savefig("caah_agbs.pdf")

# %%
fig, axs = plt.subplots(1, 2, sharey=True, gridspec_kw=dict(wspace=0), figsize=(7, 10/3))

plt.sca(axs[0])

names = ["C11_f0.2_zeta0.05_j8",
    "C11_f0.2_zeta0.1_j8",
    "C11_f0.2_zeta0.15_j8",]

labels = [r"$\zeta=0.05$", r"$\zeta=0.1$", r"$\zeta=0.15$"]

compare_cooh(names, labels, sequential=True)
plt.xlim(-0.4)
plt.ylim(-0.3, 0.05)

plt.sca(axs[1])

compare_coofe(names, labels, legend=False, sequential=True)

plt.savefig("zeta.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))


names = ["C11_f0.2_j8",
    "C11_f0.4_j8",
    "C11_f0.2_eta0.3_j8",
    "C11_f0.2_lateburst1_j8",]

labels = ["fiducial", r"$f_{\rm agb}=0.4$", r"$\eta\to0.3\eta$", "lateburst"]

compare_cooh(names, labels)
plt.savefig("caah_indifferent.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))


names = ["C11_f0.2_j8",
    "C11_f0.2_eta0.6_j8",
    "C11_f0.2_eta0.3_j8",]

labels = ["fiducial", r"$\eta\to0.6\eta$", r"$\eta\to0.3\eta$",]

compare_coofe(names, labels, sequential=True)
plt.savefig("caafe_eta.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = [    
    "C11_f0.2_j8",
    "K10_f0.2_j8",
    "V13_f0.2_j8",
    "K16_f0.2_j8",]
labels = ["C11", "K10", "V13", "K16"]

compare_coofe(names, labels)

plt.savefig("caafe_agbs.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = ["C11_f0.05_j8",
        "C11_f0.1_j8",
        "C11_f0.2_j8",
        "C11_f0.4_j8",]

labels = ["$f=0.05$", "$f=0.1$", "$f=0.2$", "$f=0.4$"]
compare_coofe(names, labels, sequential=True)
plt.savefig("caafe_fagb.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = ["A_1.3_2.3_4.3_z-0.02_f0.2_j8",
    "A_1.3_2.3_4.3_z-0.02_f0.05_j8",
         "A_1.3_2.3_4.3_z-0.02_f0.4_j8",
        ]

labels = ["$f=0.05$", "$f=0.2$", "$f=0.4$"]
compare_coofe(names, labels, sequential=True)
plt.savefig("caafe_fagb.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = ["C11_f0.2_j8", 
         "C11_f0.2_lateburst1_j8",
        "C11_f0.2_twoexp1_j8",

        ]

labels=["fiducial", "lateburst", "earlyburst"]
compare_coofe(names, labels)
plt.savefig("caafe_sfh.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = ["A_1.3_2.3_4.3_z-0.02_f0.2_j8",
"A_1.3_2.3_4.3_z-0.02_y0-1e-4_f0.2_j8",
"A_1.3_2.3_4.3_z-0.02_y2-1e-4_f0.2_j8",
        ]

labels=["fiducial", "low mass", "high mass"]
compare_coofe(names, labels)
plt.savefig("caafe_negative.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = [
    "A_1_1.5_2_z-0.02_f0.2_j8",
    "A_1.5_2_2.5_z-0.02_f0.2_j8",
    "A_2_3_4_z-0.02_f0.2_j8",
    "A_4_5_6_z-0.02_f0.2_j8",
        ]
labels = [          
    r"$M = 1.5\pm0.5$", 
    r"$M = 2 \pm 0.5$",
    r"$M=3\pm1$", 
    r"$M=5\pm1$"
]


compare_coofe(names, labels, sequential=True)
plt.savefig("caafe_magb.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))

names = [
"C11_m0.8_f0.2_j8",
    "C11_f0.2_j8",
    "C11_m1.2_f0.2_j8",
        ]
labels = [          
"shift highmass",
    "fiducial",
    "shift lowmass"
]


compare_coofe(names, labels, sequential=True)
plt.savefig("caafe_magb2.pdf")

# %%
plt.figure(figsize=(10/3, 10/3))


names = [
    "A_1.3_2.3_4.3_z-0.0_f0.2_j8",
    "A_1.3_2.3_4.3_z-0.01_f0.2_j8",
    "A_1.3_2.3_4.3_z-0.06_f0.2_j8",
    "A_1.3_2.3_4.3_z-0.1_f0.2_j8",
        ]
labels = [          
    r"$\zeta^{\rm agb} = 0$",
    r"$\zeta^{\rm agb} = -0.01$",
    r"$\zeta^{\rm agb} = -0.06$",
    r"$\zeta^{\rm agb} = -0.1$"
]


compare_coofe(names, labels, sequential=True)
plt.savefig("caafe_zagb.pdf")
