# %%
import surp
# Out:
# /astro/dboyea/.local/lib/python3.11/site-packages/vice/__init__.py:141: UserWarning: Using un-released version of VICE
#   warnings.warn("Using un-released version of VICE", UserWarning)
# warning could not find subgiants at  /astro/dboyea/.local/lib/python3.11/site-packages/surp/../data/subgiants.csv

# %%
import arya
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
m = np.logspace(np.log10(0.07), 0, 1000)
np.min(m), np.max(m)
# Out:
# (np.float64(0.07000000000000002), np.float64(1.0))

# %%
imf = [surp.yield_models.chabrier(x) for x in m]

# %%
plt.plot(np.log10(m), (imf))
