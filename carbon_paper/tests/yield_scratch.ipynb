# %%
import surp
import surp.gce_math as gcem

import matplotlib.pyplot as plt
import arya
import numpy as np
# Out:
# /astro/dboyea/.local/lib/python3.11/site-packages/vice-1.4.0.dev0-py3.11-linux-x86_64.egg/vice/__init__.py:141: UserWarning: Using un-released version of VICE
#   warnings.warn("Using un-released version of VICE", UserWarning)

# %%
x = np.linspace(-2, 3, 1000)
Z = gcem.MH_to_Z(x)

y_model = surp.yield_models.Spline_CC([0.0014, 0.016, 0.16], [ 0., 1., 0.5])
y_model = np.vectorize(y_model)
                    
plt.plot(x, y_model(Z))

# %%
gcem.Z_to_MH([0.0001, 0.0003, 0.001, 0.002, 0.003, 0.006, 0.008, 0.01, 0.014, 0.02])
# Out:
# array([-2.24551267, -1.76839141, -1.24551267, -0.94448267, -0.76839141,
#        -0.46736142, -0.34242268, -0.24551267, -0.09938463,  0.05551733])

# %%
gcem.MH_to_Z([-2, -1, -0.6, -0.4, -0.2, 0, 0.2, 0.4])
# Out:
# array([0.000176  , 0.00176   , 0.00442092, 0.00700669, 0.01110485,
#        0.0176    , 0.02789412, 0.0442092 ])
