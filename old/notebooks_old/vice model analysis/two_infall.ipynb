# %%
from surp.src.analysis.vice_model import vice_model

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
model = vice_model("../../output/C11_f0.2_eta1_beta0.001_twoexp0.5.json")

# %%
plt.rcParams["figure.dpi"] = 200

# %%
R = 8.0

df = model.history[model.history.R == R]
df
# Out:
#          time          mgas         mstar       sfr       ifr            ofr  \
# 105680   0.00  1.000000e-12  0.000000e+00  0.000000       NaN  1.183571e-316
# 105681   0.01  1.177535e+07  2.563305e+03  0.000283  1.178434   6.155407e-04
# 105682   0.02  1.770487e+07  7.455234e+03  0.000565  0.594718   1.227203e-03
# 105683   0.03  2.247571e+07  1.451854e+04  0.000845  0.479697   1.835009e-03
# 105684   0.04  2.591035e+07  2.369691e+04  0.001123  0.346912   2.438981e-03
# ...       ...           ...           ...       ...       ...            ...
# 106996  13.16  8.291996e+07  3.208555e+08  0.023909  0.062810   5.191632e-02
# 106997  13.17  8.291252e+07  3.211052e+08  0.023894  0.061969   5.188185e-02
# 106998  13.18  8.290508e+07  3.183859e+08  0.023878  0.062470   5.184741e-02
# 106999  13.19  8.289763e+07  3.184923e+08  0.023862  0.061365   5.181300e-02
# 107000  13.20  8.289018e+07  3.186000e+08  0.023846  0.061656   5.177861e-02
#
# ...

# %%
plt.scatter(df.time, df.sfr)
plt.xlabel("t (Gyr)")
plt.ylabel("SFR")
# Out:
# Text(0, 0.5, 'SFR')

# %%
model.plot_coofe()

# %%
vice.yields.agb.settings["o"] = "ventura13"

# %%
model.plot_stars?
# Out:
# Signature:
# model.plot_stars(
#     x,
#     y,
#     c=None,
#     c_label=None,
#     xlim=None,
#     star_group='solar',
#     exclude_high_alpha=True,
#     plot_data=True,
#     **kwargs,
# )
# Docstring: <no docstring>
# File:      ~/python/surp/src/analysis/vice_model.py
# Type:      method

# %%
model.plot_stars("[fe/h]", "[o/fe]", exclude_high_alpha=False, star_group="apogee")
plt.xlim(-1, 0.6)
plt.ylim(-0.3, 0.4)
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.9/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'xlim'
#   cset = contour_func(
# (-0.3, 0.4)

# %%
s = model.stars["apogee"]

plt.hist2d(s["[fe/h]"], s["[mg/fe]"], range=((-1, 0.5), (-0.1, 0.4)), cmin=1, bins=50);

# %%
model.plot_mdf("[mg/fe]")
# Out:
# /users/PAS2232/aeyobd/python/surp/src/analysis/apogee_analysis.py:177: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   return pd.DataFrame(df, dtype=float)

# %%
model.plot_stars("[mg/h]", "[n/mg]", exclude_high_alpha=False, star_group="apogee")
plt.xlim(-1, 0.6)
plt.ylim(-0.3, 0.4)
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.9/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'xlim'
#   cset = contour_func(
# (-0.3, 0.4)

# %%
model.plot_stars("[fe/h]", "[mg/fe]", exclude_high_alpha=False, star_group="apogee")
plt.xlim(-1, 0.6)
plt.ylim(-0.3, 0.4)
# Out:
# /users/PAS2232/aeyobd/.local/lib/python3.9/site-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'xlim'
#   cset = contour_func(
# (-0.3, 0.4)

# %%
vice.single_stellar_population("mg", Z=0.1)[0][-1]/1e6 - vice.yields.ccsne.settings["mg"]
# Out:
# 1.2161076543805807e-05

# %%
0.000509/vice.solar_z("mg")
# Out:
# 0.7209631728045326

# %%
vice.yields.ccsne.settings["mg"]
# Out:
# 0.000497

# %%
vice.solar_z("mg")/vice.solar_z("o")
# Out:
# 0.12342657342657343

# %%
vice.yields.ccsne.settings["o"]
# Out:
# 0.015

# %%
0.015*0.1234
# Out:
# 0.0018509999999999998
