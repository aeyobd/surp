# %% [markdown]
# ```
# select top 1000 mass_flame, vsini_esphs, flags_esphs from gaiadr3.astrophysical_parameters as ap
# where ap.flags_esphs = '01'
# and ap.flags_flame = '00'
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotting

# %%
df = pd.read_csv("1655826358670O-result.csv")

# %%
plotting.density_scatter(df.mass_flame, df.vsini_esphs, density=False);
plt.xlabel("Mass")
plt.ylabel("v sin i")
# Out:
# Text(0, 0.5, 'v sin i')
